# %% [markdown]
# <a href="https://colab.research.google.com/github/AHMADAMJAD0/Deep-Learning-/blob/main/What_is_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("deep learning ")
# Out:
# deep learning

# %% [markdown]
# ![1-min.png](data:image/png;base64,...)

# %% [markdown]
# ![2-min.png](data:image/png;base64,...)

# %% [markdown]
# ![3-min.png](data:image/png;base64,...)
