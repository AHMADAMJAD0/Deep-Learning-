# %% [markdown]
# <a href="https://colab.research.google.com/github/AHMADAMJAD0/Deep-Learning-/blob/main/8__Neural_Network_Backpropagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("ahmad")
# Out:
# ahmad

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![13-min.png](data:image/png;base64,...)

# %%
print("training ")
# Out:
# training

# %% [markdown]
# ![Screenshot 2026-08-20 at 4.15.42 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![1234-min.png](data:image/png;base64,...)
