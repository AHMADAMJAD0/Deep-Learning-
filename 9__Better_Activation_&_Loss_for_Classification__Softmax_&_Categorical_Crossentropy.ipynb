# %% [markdown]
# <a href="https://colab.research.google.com/github/AHMADAMJAD0/Deep-Learning-/blob/main/9__Better_Activation_%26_Loss_for_Classification__Softmax_%26_Categorical_Crossentropy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hy")
# Out:
# hy

# %% [markdown]
# ![344.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
