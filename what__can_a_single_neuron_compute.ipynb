# %% [markdown]
# <a href="https://colab.research.google.com/github/AHMADAMJAD0/Deep-Learning-/blob/main/what__can_a_single_neuron_compute.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![ChatGPT Image Jul 27, 2026, 10_17_04 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![5-min.png](data:image/png;base64,...)

# %% [markdown]
# 1 dimention input x1 produce 1 dimention output y and mapping from the input to output will be a linear function
#
# (x1 * weight ) + bias -> activation function -> produce the output = y
#
# will be **linear function**
#
#
# and
#
# this type of function could use for regression and then regression problem would be chose specific linear function

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Regression aur Classification — image ki easy explanation**
#
# Is image mein dikhaya gaya hai ke same neuron ko do different tasks ke liye use kiya ja sakta hai:
#
# Regression: exact numerical value predict karna
# Classification: category predict karna
#
# Neuron pehle weighted sum calculate karta hai:
#
# z=x
# 1
# 	​
#
# w
# 1
# 	​
#
# +x
# 2
# 	​
#
# w
# 2
# 	​
#
# +⋯+b
#
# Phir activation function decide karti hai ke final output y kya hoga.
#
# 1. Regression
#
# Regression mein output ek continuous number hota hai.
#
# Examples:
#
# House price = $250,000
# Temperature = 32.5
# ∘
# Student marks = 87
# Salary = $65,000
#
# Image mein sirf ek input hai:
#
# z=x
# 1
# 	​
#
# w
# 1
# 	​
#
# +b
#
# Regression ke liye linear activation use ho rahi hai:
#
# y=z
#
# Yani weighted sum hi final output ban jata hai.
#
# Image ka example
# w
# 1
# 	​
#
# =3,b=−2
#
# Is liye:
#
# y=3x
# 1
# 	​
#
# −2
#
# Agar:
#
# x
# 1
# 	​
#
# =2
#
# To:
#
# y=3(2)−2
# y=6−2=4
# Visual process
# Input x₁ = 2
#       ↓
# Multiply by weight 3
#       ↓
# 6
#       ↓
# Add bias −2
#       ↓
# Output y = 4
# Regression graph
#
# Graph mein dots actual training examples hain.
#
# Red line:
#
# y=3x
# 1
# 	​
#
# −2
#
# model ki prediction line hai.
#
# Dots = actual answers
# Line = model predictions
#
# Model weights aur bias ko train karke aisi line find karta hai jo dots ke maximum qareeb ho.
#
# Weight ka role
# w
# 1
# 	​
#
# =3
#
# Weight line ka slope control karta hai.
#
# Bara positive weight → line zyada tezi se upar
# Negative weight → line neeche
# Chhota weight → flatter line
# Bias ka role
# b=−2
#
# Bias line ko upar ya neeche shift karta hai.
#
# 2. Classification
#
# Classification mein output ek category hoti hai.
#
# Examples:
#
# Spam or not spam
# Cat or dog
# Disease or no disease
# Pass or fail
#
# Image mein two inputs hain:
#
# z=x
# 1
# 	​
#
# w
# 1
# 	​
#
# +x
# 2
# 	​
#
# w
# 2
# 	​
#
# +b
#
# Phir step activation function lagti hai:
#
# y={
# 0,
# 1,
# 	​
#
# z≤0
# z>0
# 	​
#
#
# Simple meaning:
#
# Weighted sum z ≤ 0 → Class 0
# Weighted sum z > 0 → Class 1
# Classification example
#
# Image mein:
#
# w
# 1
# 	​
#
# =2,w
# 2
# 	​
#
# =−1,b=1
#
# Therefore:
#
# z=2x
# 1
# 	​
#
# −x
# 2
# 	​
#
# +1
#
# Suppose:
#
# x
# 1
# 	​
#
# =2,x
# 2
# 	​
#
# =3
#
# Then:
#
# z=2(2)−3+1
# z=4−3+1=2
#
# Because:
#
# z>0
#
# Therefore:
#
# y=1
# Another example
#
# Suppose:
#
# x
# 1
# 	​
#
# =0,x
# 2
# 	​
#
# =3
#
# Then:
#
# z=2(0)−3+1=−2
#
# Because:
#
# z≤0
#
# Therefore:
#
# y=0
# 3. Classification graph ke dots
#
# Graph mein do types ke dots hain:
#
# Ek color = Class 0
# Doosra color = Class 1
#
# Red line ko decision boundary kehte hain.
#
# Line ki ek side → y = 0
# Line ki doosri side → y = 1
#
# Decision boundary us jagah hoti hai jahan:
#
# z=0
#
# Given:
#
# 2x
# 1
# 	​
#
# −x
# 2
# 	​
#
# +1=0
#
# Isko rearrange karein:
#
# x
# 2
# 	​
#
# =2x
# 1
# 	​
#
# +1
#
# Yeh equation graph par red line banati hai.
#
# 4. Decision boundary ka simple example
#
# Imagine school ground mein ek line draw kar di:
#
# Left side  → Team 0
# Right side → Team 1
#
# Isi tarah classification neuron data points ko line ki position ke according class deta hai.
#
# 5. Image mein “1D” ka meaning
#
# 1D ka matlab hai sirf ek input feature.
#
# For example:
#
# z=wx+b
#
# Agar classification one-dimensional ho, decision boundary ek single point hota hai:
#
# Class 0  ←─────|─────→  Class 1
#               boundary
#
# Two-dimensional classification mein inputs x
# 1
# 	​
#
#  aur x
# 2
# 	​
#
#  hote hain, is liye decision boundary ek line hoti hai.
#
# 1 input  → boundary is a point
# 2 inputs → boundary is a line
# 3 inputs → boundary is a plane
# Regression vs Classification
# Regression	Classification
# Number predict karti hai	Category predict karti hai
# Output continuous hota hai	Output discrete hota hai
# Example: price	Example: spam/not spam
# Line data ko fit karti hai	Boundary classes separate karti hai
# Output: 4.7, 20, 150	Output: 0 or 1
# Main idea
#
# Regression mein neuron ek numerical value deta hai, jabke classification mein neuron decision boundary ke basis par class 0 ya class 1 deta hai.

# %% [markdown]
# ![6-min.png](data:image/png;base64,...)

# %% [markdown]
# How do we train a neuron? — bohat simple explanation
#
# Neuron ko train karne ka matlab hai:
#
# Weights w aur bias b ko aise adjust karna ke neuron ki predictions correct answer ke qareeb ho jayein.
#
# 1. Dataset contains input/output examples
#
# Dataset mein har example ke do parts hote hain:
#
# (
# x
# ,y)
# x
#  = input
# y = correct output or label
# Example: House-price prediction
# x=house size
# y=actual house price
# Input x	Correct output y
# 1,000 sq. ft.	$150,000
# 1,500 sq. ft.	$220,000
# 2,000 sq. ft.	$290,000
#
# Neuron inputs ko dekhta hai aur output predict karta hai.
#
# 2. Neuron prediction banata hai
#
# Neuron ki calculation:
#
# z=w
# 1
# 	​
#
# x
# 1
# 	​
#
# +w
# 2
# 	​
#
# x
# 2
# 	​
#
# +⋯+w
# n
# 	​
#
# x
# n
# 	​
#
# +b
#
# Phir activation function:
#
# y
# ^
# 	​
#
# =f(z)
#
# Yahan:
#
# w
# 1
# 	​
#
# ,…,w
# n
# 	​
#
#  = weights
# b = bias
# y
# ^
# 	​
#
#  = model ki predicted value
# y = actual correct value
#
# Notice:
#
# y=correct answer
# y
# ^
# 	​
#
# =model prediction
# 3. Loss function kya karti hai?
#
# Loss function measure karti hai ke prediction kitni wrong hai.
#
# Correct answer y
#         ↘
#          Compare → Loss
#         ↗
# Prediction ŷ
#
# Prediction actual answer se door ho:
#
# Large loss
#
# Prediction actual answer ke qareeb ho:
#
# Small loss
#
# Perfect prediction:
#
# Loss=0
# 4. Simple loss example
#
# Suppose actual answer:
#
# y=10
#
# Neuron prediction:
#
# y
# ^
# 	​
#
# =7
#
# Simple squared-error loss:
#
# L=(y−
# y
# ^
# 	​
#
# )
# 2
# L=(10−7)
# 2
# =9
#
# Ab maan lein training ke baad new prediction:
#
# y
# ^
# 	​
#
# =9
#
# Then:
#
# L=(10−9)
# 2
# =1
#
# Loss 9 se 1 ho gaya. Iska matlab model improve hua.
#
# Image mein L(w
# 1
# 	​
#
# ,…,w
# n
# 	​
#
# ,b) ka meaning
# L(w
# 1
# 	​
#
# ,…,w
# n
# 	​
#
# ,b)
#
# Iska matlab hai:
#
# Model ki total mistake weights aur bias par depend karti hai.
#
# Weights aur bias change honge to:
#
# Prediction change hogi
# Prediction change hogi to loss change hoga
# Weights and bias
#        ↓
# Prediction
#        ↓
# Loss
#
# Goal:
#
# Aise weights aur bias find karo jo loss minimum kar dein
# 	​
#
# 5. Neuron train kaise hota hai?
# Step 1: Random weights aur bias
#
# Starting mein:
#
# w
# 1
# 	​
#
# ,w
# 2
# 	​
#
# ,…,b
#
# random values ho sakti hain.
#
# Step 2: Prediction
# y
# ^
# 	​
#
# =f(w⋅x+b)
# Step 3: Loss calculate
# L(y,
# y
# ^
# 	​
#
# )
# Step 4: Gradients calculate
#
# Gradient batata hai:
#
# Kis weight ko kis direction mein change karne se loss kam hoga?
#
# Step 5: Weights update
# w
# new
# 	​
#
# =w
# old
# 	​
#
# −η
# ∂w
# ∂L
# 	​
#
# b
# new
# 	​
#
# =b
# old
# 	​
#
# −η
# ∂b
# ∂L
# 	​
#
# Step 6: Repeat
#
# Yeh process baar-baar repeat hota hai:
#
# Input
#   ↓
# Prediction
#   ↓
# Calculate loss
#   ↓
# Calculate gradients
#   ↓
# Update weights and bias
#   ↓
# Make a better prediction
# Small complete example
#
# Suppose:
#
# x=2,y=7
#
# Starting values:
#
# w=2,b=1
#
# Neuron prediction:
#
# y
# ^
# 	​
#
# =wx+b
# y
# ^
# 	​
#
# =2(2)+1=5
#
# Actual answer:
#
# y=7
#
# Loss:
#
# L=(7−5)
# 2
# =4
#
# Model weights aur bias update karta hai.
#
# Suppose new values:
#
# w=3,b=1
#
# New prediction:
#
# y
# ^
# 	​
#
# =3(2)+1=7
#
# New loss:
#
# L=(7−7)
# 2
# =0
#
# Neuron ne correct relationship seekh liya.
#
# Training in one line
#
# Neuron prediction banata hai, loss function uski mistake measure karti hai, aur gradient descent weights aur bias ko update karke mistake kam karta hai.
