# %% [markdown]
# <a href="https://colab.research.google.com/github/AHMADAMJAD0/Deep-Learning-/blob/main/How_to_train_neuron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![9-min.png](data:image/png;base64,...)

# %% [markdown]
# Regression and Classification Using One Neuron
# 1. Basic Idea of a Neuron
#
# Ek single neuron do different tasks perform kar sakta hai:
#
# Regression: kisi numerical value ki prediction
# Classification: kisi category ya class ki prediction
#
# Dono problems mein neuron sab se pehle weighted sum calculate karta hai:
#
# z=w1​x1​+w2​x2​+⋯+wn​xn​+b
# Symbols ka meaning
# x
# 1
# 	​
#
# ,x
# 2
# 	​
#
# ,…,x
# n
# 	​
#
#  = input features
# w
# 1
# 	​
#
# ,w
# 2
# 	​
#
# ,…,w
# n
# 	​
#
#  = weights
# b = bias
# z = weighted sum
# f(z) = activation function
# y
# ^
# 	​
#
#  = model ki prediction
# y = actual correct answer
# Complete neuron flow
#
# Input features
# ↓
# Har input ko uske weight se multiply karo
# ↓
# Sab weighted values ko add karo
# ↓
# Bias add karo
# ↓
# Weighted sum z hasil karo
# ↓
# Activation function apply karo
# ↓
# Prediction
# y
# ^
# 	​
#
#  hasil karo
#
# Part 1: Regression
# 2. Regression kya hoti hai?
#
# Regression ka use tab hota hai jab model ko numerical value predict karni ho.
#
# Examples
# House price
# Temperature
# Salary
# Student marks
# Product sales
# Weight
# Speed
# Simple example
#
# House size
# ↓
# Regression model
# ↓
# Predicted house price = $250,000
#
# Regression mein output koi category nahi hota. Output ek numerical value hota hai.
#
# 3. Continuous Numerical Value
#
# Continuous numerical value aisa number hota hai jo decimal mein bhi ho sakta hai.
#
# Examples
# Temperature: 36.5
# ∘
# C
# Height: 1.73 meters
# Weight: 70.25 kg
# Speed: 62.8 km/h
# House price: $250,500.75
#
# Do continuous values ke darmiyan aur bhi bohat si values ho sakti hain:
#
# 5.1,5.11,5.115,5.116
# Continuous aur Discrete ka difference
# Continuous value	Discrete value
# Weight = 72.5 kg	Students = 25
# Temperature = 31.7
# ∘
# C	Cars = 4
# Height = 1.73 m	Children = 3
#
# Continuous values measurement hoti hain, jabke discrete values usually counting hoti hain.
#
# 4. Regression Neuron with One Input
#
# Suppose neuron ke paas:
#
# Input = x
# 1
# 	​
#
# Weight = w
# 1
# 	​
#
# Bias = b
#
# Neuron weighted sum calculate karta hai:
#
# z=w
# 1
# 	​
#
# x
# 1
# 	​
#
# +b
#
# Regression mein linear activation use ki ja sakti hai:
#
# f(z)=z
#
# Is liye final prediction:
#
# y
# ^
# 	​
#
# =w
# 1
# 	​
#
# x
# 1
# 	​
#
# +b
# 5. Actual Value aur Predicted Value
# y = actual correct value
# y
# ^
# 	​
#
#  = model ki predicted value
#
# Example:
#
# y=10
# y
# ^
# 	​
#
# =8
#
# Model ki prediction actual answer se 2 units different hai.
#
# 6. Weight ka Role
#
# Weight input ki importance aur regression line ki slope control karta hai.
#
# Weight ka effect
# Positive weight → line upar jati hai
# Negative weight → line neeche jati hai
# Bara weight → line zyada steep hoti hai
# Chhota weight → line flatter hoti hai
#
# Example:
#
# y
# ^
# 	​
#
# =2x
#
# Yahan weight 2 hai.
#
# 7. Bias ka Role
#
# Bias regression line ko upar ya neeche shift karta hai.
#
# Example:
#
# y
# ^
# 	​
#
# =2x
#
# Yeh line origin se guzarti hai.
#
# Lekin:
#
# y
# ^
# 	​
#
# =2x−2
#
# Yeh line 2 units neeche shift ho jati hai.
#
# Weight line ka angle control karta hai, jabke bias line ki position control karta hai.
#
# 8. Regression Dataset
#
# Dataset:
#
# Input x
# 1
# 	​
#
# 	Actual value y
# 1	1
# 2	3
# 3	2
# 4	4
#
# Current model parameters:
#
# w
# 1
# 	​
#
# =2
# b=−2
#
# Model equation:
#
# y
# ^
# 	​
#
# =2x
# 1
# 	​
#
# −2
# 9. Predictions Calculate Karna
# Example 1
# x
# 1
# 	​
#
# =1
# y
# ^
# 	​
#
# =2(1)−2=0
#
# Actual value:
#
# y=1
#
# Prediction:
#
# y
# ^
# 	​
#
# =0
# Example 2
# x
# 1
# 	​
#
# =2
# y
# ^
# 	​
#
# =2(2)−2=2
#
# Actual value:
#
# y=3
#
# Prediction:
#
# y
# ^
# 	​
#
# =2
# Example 3
# x
# 1
# 	​
#
# =3
# y
# ^
# 	​
#
# =2(3)−2=4
#
# Actual value:
#
# y=2
#
# Prediction:
#
# y
# ^
# 	​
#
# =4
# Example 4
# x
# 1
# 	​
#
# =4
# y
# ^
# 	​
#
# =2(4)−2=6
#
# Actual value:
#
# y=4
#
# Prediction:
#
# y
# ^
# 	​
#
# =6
# 10. Complete Prediction Table
# Input x
# 1
# 	​
#
# 	Actual y	Predicted
# y
# ^
# 	​
#
#
# 1	1	0
# 2	3	2
# 3	2	4
# 4	4	6
# 11. Regression Graph
#
# Graph mein:
#
# Black dots = actual data points
# Red line = model ki predictions
#
# Model line:
#
# y
# ^
# 	​
#
# =2x−2
#
# Agar red line actual data points ke qareeb ho, model ki prediction achhi hai.
#
# Agar line points se door ho, model ki error zyada hai.
#
# Actual point aur prediction line ke darmiyan vertical distance ko error ya residual kehte hain.
#
# 12. Mean Squared Error — MSE
#
# Mean Squared Error regression model ki total mistake measure karta hai.
#
# Formula:
#
# MSE=
# N
# 1
# 	​
#
# i=1
# ∑
# N
# 	​
#
# (y
# i
# 	​
#
# −
# y
# ^
# 	​
#
# i
# 	​
#
# )
# 2
# MSE calculate karne ke steps
# Actual value aur prediction ka difference nikalo
# Difference ko square karo
# Sab squared errors add karo
# Total examples N se divide karo
# 13. MSE Calculation
# First example
# (1−0)
# 2
# =1
# Second example
# (3−2)
# 2
# =1
# Third example
# (2−4)
# 2
# =(−2)
# 2
# =4
# Fourth example
# (4−6)
# 2
# =(−2)
# 2
# =4
#
# Squared errors ka sum:
#
# 1+1+4+4=10
#
# Total examples:
#
# N=4
#
# Therefore:
#
# MSE=
# 4
# 10
# 	​
#
# =2.5
# MSE=2.5
# 	​
#
# 14. MSE ko Kaise Samjhein?
# MSE=0 → predictions bilkul perfect hain
# Small MSE → predictions actual values ke qareeb hain
# Large MSE → predictions actual values se door hain
#
# Model training ka goal MSE ko minimum karna hota hai.
#
# 15. Regression Model Training
#
# Regression model training ka process:
#
# Input model ko do
# ↓
# Prediction
# y
# ^
# 	​
#
#  banao
# ↓
# MSE loss calculate karo
# ↓
# Gradients calculate karo
# ↓
# Weight aur bias update karo
# ↓
# Dobara prediction banao
# ↓
# Loss ko aur kam karo
#
# 16. Gradient ka Role
#
# Weight ka gradient:
#
# ∂w
# 1
# 	​
#
# ∂L
# 	​
#
#
# Yeh batata hai:
#
# Weight w
# 1
# 	​
#
#  ko change karne se loss par kya effect hoga?
#
# Bias ka gradient:
#
# ∂b
# ∂L
# 	​
#
#
# Yeh batata hai:
#
# Bias ko change karne se loss par kya effect hoga?
#
# Gradient direction batata hai. Optimizer actual parameters update karta hai.
#
# 17. Parameter Update Formula
#
# Weight update:
#
# w
# new
# 	​
#
# =w
# old
# 	​
#
# −η
# ∂w
# ∂L
# 	​
#
#
# Bias update:
#
# b
# new
# 	​
#
# =b
# old
# 	​
#
# −η
# ∂b
# ∂L
# 	​
#
#
# Yahan:
#
# η = learning rate
# Learning rate step ka size control karti hai
# Optimizer gradient ki opposite direction mein move karta hai
#
# Goal:
#
# Aise weights aur bias find karna jo prediction line ko actual points ke qareeb le aayein.
#
# Part 2: Classification
# 18. Classification kya hoti hai?
#
# Classification ka use tab hota hai jab model ko koi class ya category predict karni ho.
#
# Examples
# Spam / Not Spam
# Disease / No Disease
# Pass / Fail
# Cat / Dog
# Fraud / Not Fraud
#
# Binary classification mein classes ko aksar:
#
# 0aur1
#
# se represent kiya jata hai.
#
# 19. Classification Neuron with Two Inputs
#
# Suppose neuron ke paas:
#
# x
# 1
# 	​
#
# ,x
# 2
# 	​
#
#
# do inputs hain.
#
# Inke weights:
#
# w
# 1
# 	​
#
# ,w
# 2
# 	​
#
#
# Aur bias:
#
# b
#
# Neuron score calculate karta hai:
#
# z=w
# 1
# 	​
#
# x
# 1
# 	​
#
# +w
# 2
# 	​
#
# x
# 2
# 	​
#
# +b
#
# Yeh z abhi final class nahi hai. Yeh model ka raw score hai.
#
# 20. Step Activation Function
#
# Simple classification explanation ke liye step function use ki ja sakti hai:
#
# y
# ^
# 	​
#
# ={
# 0,
# 1,
# 	​
#
# z≤0
# z>0
# 	​
#
#
# Meaning:
#
# z≤0 → Class 0
# z>0 → Class 1
#
# Examples:
#
# z=−3⇒
# y
# ^
# 	​
#
# =0
# z=0⇒
# y
# ^
# 	​
#
# =0
# z=2⇒
# y
# ^
# 	​
#
# =1
#
# Step function score ko directly class mein convert karti hai.
#
# 21. Classification Dataset
# x
# 1
# 	​
#
# 	x
# 2
# 	​
#
# 	Actual class y
# 1	2	0
# 2	1	0
# 2	3	1
# 3	2	1
# 4	1	0
# 4	2	1
#
# Yahan:
#
# x
# 1
# 	​
#
# ,x
# 2
# 	​
#
#  = input features
# y = actual class
# Example: Student Pass/Fail
# x
# 1
# 	​
#
#  = attendance
# x
# 2
# 	​
#
#  = marks
# y = pass/fail
# Example: Spam Detection
# x
# 1
# 	​
#
#  = suspicious words ki quantity
# x
# 2
# 	​
#
#  = unknown links ki quantity
# y = spam/not spam
# 22. Classification Parameters Example
#
# Suppose:
#
# w
# 1
# 	​
#
# =2
# w
# 2
# 	​
#
# =−1
# b=1
#
# Then:
#
# z=2x
# 1
# 	​
#
# −x
# 2
# 	​
#
# +1
#
# Decision rule:
#
# z≤0⇒
# y
# ^
# 	​
#
# =0
# z>0⇒
# y
# ^
# 	​
#
# =1
# 23. Classification Prediction Example
#
# Suppose:
#
# x
# 1
# 	​
#
# =2
# x
# 2
# 	​
#
# =3
#
# Score:
#
# z=2(2)−3+1
# z=4−3+1
# z=2
#
# Because:
#
# z>0
#
# Therefore:
#
# y
# ^
# 	​
#
# =1
# 	​
#
#
# Model ne Class 1 predict ki.
#
# 24. Decision Boundary
#
# Decision boundary woh jagah hoti hai jahan:
#
# z=0
#
# For this model:
#
# 2x
# 1
# 	​
#
# −x
# 2
# 	​
#
# +1=0
#
# Rearranging:
#
# x
# 2
# 	​
#
# =2x
# 1
# 	​
#
# +1
#
# Decision boundary data ko do regions mein divide karti hai:
#
# Boundary ki aik side → Class 0
# Boundary ki doosri side → Class 1
#
# Weights boundary ka angle control karte hain.
#
# Bias boundary ko shift karta hai.
#
# Important Correction
#
# Equation:
#
# x
# 2
# 	​
#
# =2x
# 1
# 	​
#
# +1
#
# upward-sloping line banati hai. Agar kisi diagram mein downward-sloping line ho, to diagram aur equation match nahi karte.
#
# 25. Step Function aur Sigmoid ka Difference
# Step Function
#
# Step function direct class deti hai:
#
# 0or1
#
# Lekin step function smooth nahi hoti. Is liye gradient-based neural-network training ke liye useful nahi hoti.
#
# Sigmoid Function
#
# Practical binary classification mein sigmoid use ki ja sakti hai:
#
# σ(z)=
# 1+e
# −z
# 1
# 	​
#
#
# Sigmoid output ko probability mein convert karti hai:
#
# 0<
# y
# ^
# 	​
#
# <1
#
# Examples:
#
# y
# ^
# 	​
#
# =0.90
#
# Class 1 ka high chance.
#
# y
# ^
# 	​
#
# =0.20
#
# Class 1 ka low chance.
#
# 26. Sigmoid Threshold
#
# Probability ko final class mein convert karne ke liye threshold use hota hai:
#
# y
# ^
# 	​
#
# ≥0.5⇒Class 1
# y
# ^
# 	​
#
# <0.5⇒Class 0
#
# Complete flow:
#
# Weighted score z
# ↓
# Sigmoid function
# ↓
# Probability
# ↓
# Threshold 0.5
# ↓
# Class 0 or Class 1
#
# 27. Binary Cross-Entropy Loss
#
# Binary classification mein commonly Binary Cross-Entropy ya Log Loss use hoti hai.
#
# Formula:
#
# L=−
# N
# 1
# 	​
#
# i=1
# ∑
# N
# 	​
#
# [y
# i
# 	​
#
# log(
# y
# ^
# 	​
#
# i
# 	​
#
# )+(1−y
# i
# 	​
#
# )log(1−
# y
# ^
# 	​
#
# i
# 	​
#
# )]
#
# Is formula ka simple meaning:
#
# Correct class ko high probability → small loss
# Correct class ko low probability → large loss
# Confident wrong prediction → bohat large loss
# 28. Binary Cross-Entropy Example
# Correct and Confident Prediction
#
# Actual class:
#
# y=1
#
# Prediction:
#
# y
# ^
# 	​
#
# =0.95
#
# Model ne correct class ko high probability di, is liye loss small hoga.
#
# Wrong and Confident Prediction
#
# Actual class:
#
# y=1
#
# Prediction:
#
# y
# ^
# 	​
#
# =0.05
#
# Model confidently wrong hai, is liye loss bohat large hoga.
#
# Cross-entropy confident wrong predictions ko zyada punishment deti hai.
#
# 29. Classification Training Process
#
# Classification model training:
#
# Inputs x
# 1
# 	​
#
# ,x
# 2
# 	​
#
#
# ↓
# Weighted score z calculate karo
# ↓
# Sigmoid se probability
# y
# ^
# 	​
#
#  nikalo
# ↓
# Actual label y se compare karo
# ↓
# Cross-entropy loss calculate karo
# ↓
# Gradients calculate karo
# ↓
# Weights w
# 1
# 	​
#
# ,w
# 2
# 	​
#
#  aur bias b update karo
# ↓
# Better decision boundary hasil karo
#
# 30. Classification Gradients
#
# Model ke parameters:
#
# w
# 1
# 	​
#
# ,w
# 2
# 	​
#
# ,b
#
# Inke gradients:
#
# ∂w
# 1
# 	​
#
# ∂L
# 	​
#
# ∂w
# 2
# 	​
#
# ∂L
# 	​
#
# ∂b
# ∂L
# 	​
#
#
# Gradient batata hai ke har parameter ko kis direction mein change karna chahiye.
#
# Optimizer parameters update karta hai taake:
#
# Class 0 ke points correct side par aayein
# Class 1 ke points correct side par aayein
# Total loss kam hota jaye
# Regression vs Classification
# Point	Regression	Classification
# Goal	Number predict karna	Category predict karna
# Examples	Price, temperature	Spam/not spam
# Output	Numerical value	Class/probability
# Weighted score	z=wx+b	z=w
# 1
# 	​
#
# x
# 1
# 	​
#
# +w
# 2
# 	​
#
# x
# 2
# 	​
#
# +b
# Activation	Linear	Sigmoid/Softmax
# Common loss	MSE	Cross-Entropy
# Graph	Best-fit line	Decision boundary
# Training goal	Line ko data ke qareeb lana	Classes ko separate karna
# Complete Regression Flow
#
# Numerical inputs
# ↓
# Linear neuron
# ↓
# Numerical prediction
# ↓
# MSE loss
# ↓
# Gradients
# ↓
# Weights aur bias update
# ↓
# Better numerical prediction
#
# Complete Classification Flow
#
# Input features
# ↓
# Weighted score
# ↓
# Sigmoid probability
# ↓
# Cross-entropy loss
# ↓
# Gradients
# ↓
# Weights aur bias update
# ↓
# Better class prediction
#
# Final Key Points
# Neuron inputs ko weights se multiply karta hai.
# Weighted values ko add karke bias add kiya jata hai.
# Result ko weighted score z kehte hain.
# Activation function z ko final output mein convert karti hai.
# Regression numerical value predict karti hai.
# Classification class ya probability predict karti hai.
# Regression mein commonly linear activation aur MSE use hoti hai.
# Binary classification mein commonly sigmoid aur cross-entropy use hoti hai.
# Loss model ki mistake measure karta hai.
# Gradient direction batata hai.
# Optimizer weights aur bias update karta hai.
# Training ka main goal loss ko minimum karna hota hai.

# %% [markdown]
# ![10-min.png](data:image/png;base64,...)

# %% [markdown]
# ![11-min.png](data:image/png;base64,...)
